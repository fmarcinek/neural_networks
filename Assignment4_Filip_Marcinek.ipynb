# %% [markdown]
# <a href="https://colab.research.google.com/github/janchorowski/nn_assignments/blob/nn18/assignment4/Assignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Starter code: network for Irises in Pytorch
#
#
# In the following cells a feedforward neural network has been implemented with the aid of PyTorch and its autograd mechanism. Please study the code - many network implementations follow a similar pattern.
#
# The provided network trains to nearly 100% accuracy on Iris using Batch Gradient Descent.

# %% [markdown]
# # Assignment 4
#
# **Submission deadline:**
#
# **problems 1-2 last lab session before or on Wednesday, 30.11.18**
#
# **problems 3-8 last lab session before or on Wednesday, 7.12.18**
#
#
# **Points: 11 + 5 bonus points**
#
#
# ## Downloading this notebook
#
# This assignment is an Colab/Jupyter notebook. Download it by cloning https://github.com/janchorowski/nn_assignments. Follow the instructions in its README for instructions.
#
# Please do not hesitate to use GitHub’s pull requests to send us corrections!
#
# If you use Colab please make sure to have a GPU runtime (```Runtime -> Change runtime type -> Hardware Accelarater = GPU```)

# %%
# Please note that this code needs only to be run in a fresh runtime.
# However, it can be rerun afterwards too.
# !pip install -q gdown httpimport
![ -e cifar.npz ] || gdown 'https://drive.google.com/uc?id=1oBzZdtg2zNTPGhbRy6DQ_wrf5L5OAhNR' -O cifar.npz
![ -e mnist.npz ] || gdown 'https://drive.google.com/uc?id=1QPaC3IKB_5tX6yIZgRgkpcqFrfVqPTXU' -O mnist.npz

# http://pytorch.org/
from os.path import exists
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
cuda_output = !ldconfig -p|grep cudart.so|sed -e 's/.*\.\([0-9]*\)\.\([0-9]*\)$/cu\1\2/'
accelerator = cuda_output[0] if exists('/dev/nvidia0') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.1-{platform}-linux_x86_64.whl torchvision
import torch
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1oBzZdtg2zNTPGhbRy6DQ_wrf5L5OAhNR
# To: /content/cifar.npz
# 185MB [00:02, 90.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1QPaC3IKB_5tX6yIZgRgkpcqFrfVqPTXU
# To: /content/mnist.npz
# 55.4MB [00:00, 106MB/s]
# tcmalloc: large alloc 1073750016 bytes == 0x555e216d2000 @  0x7f236dbdf2a4 0x555dca441f18 0x555dca535a85 0x555dca4554ca 0x555dca45a232 0x555dca452d0a 0x555dca45a5fe 0x555dca452d0a 0x555dca45a5fe 0x555dca452d0a 0x555dca45a5fe 0x555dca452d0a 0x555dca45ac38 0x555dca452d0a 0x555dca45a5fe 0x555dca452d0a 0x555dca45a5fe 0x555dca45a232 0x555dca45a232 0x555dca452d0a 0x555dca45ac38 0x555dca45a232 0x555dca452d0a 0x555dca45ac38 0x555dca452d0a 0x555dca45ac38 0x555dca452d0a 0x555dca45a5fe 0x555dca452d0a 0x555dca452629 0x555dca48361f

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Getting to know PyTorch
#
# From now on, we will use [pytorch](https://pytorch.org/) to implement neural networks.
#
# Good introductions are the [60-minute tutorial](https://pytorch.org/tutorials/beginner/deep_learning_60min_blitz.html) and [pytorch examples](https://pytorch.org/tutorials/beginner/pytorch_with_examples.html).
#
#
# Pytorch has a set of modules to build neural networks. However, for simplicity, this assignment will use a custom, simple neural network code.

# %%
import numpy as np
import time
import torch
import torch.nn.functional as F


class Layer(object):
    
    def train_mode(self):
        """Put layer into training mode.
        
        This is useful for e.g. Dropout.
        """
        pass
    
    def eval_mode(self):
        """Put layer into evalation mode.
        
        This is useful for e.g. Dropout.
        """
        pass
    
    def to_device(self, device):
        """Move this layer's parameters to thie given device (cpu/cuda).
        """
        
        pass
    
    @property
    def parameters(self):
        return []
    
    def __repr__(self):
        param_s = ', '.join(['%s%s' % (n, tuple(p.size())) 
                                 for (n,p) in self.parameters])
        if not param_s:
            return '  %s with no params' % (self.__class__.__name__)
        else:
            return '  %s with params: %s' % (self.__class__.__name__, param_s)
    

class AffineLayer(Layer):
    def __init__(self, num_in, num_out):
        self.W = torch.empty(num_in, num_out, dtype=torch.float32, requires_grad=True)
        self.b = torch.empty(1, num_out, dtype=torch.float32, requires_grad=True)
    
    @property
    def parameters(self):
        return [('W', self.W), ('b', self.b)]
    
    def forward(self, x):
        return x.mm(self.W) + self.b
    
    def to_device(self, device):
        with torch.no_grad():
            self.W = self.W.to(device).requires_grad_()
            self.b = self.b.to(device).requires_grad_()

    
class TanhLayer(Layer):
    def forward(self, x):
        return F.tanh(x)

    
class  ReLULayer(Layer):
    def forward(self, x):
        return F.relu(x)


class SoftMaxLayer(Layer):
    def forward(self, x):
        return F.softmax(x, dim=-1)

class CrossEntropyLoss:
    def forward(self, probs, targets):
        return torch.mean(-torch.log(torch.gather(
            probs, 1, targets.unsqueeze(1))))

# %%
class FeedforwardNet(object):
    def __init__(self, layers):
        self.layers = layers
        self.loss_fn = CrossEntropyLoss()

    @property
    def parameters(self):
        params = []
        for layer in self.layers:
            params += layer.parameters
        return params

    @parameters.setter
    def parameters(self, values):
        for (_, ownP), newP in zip(self.parameters, values):
            ownP.data = newP.data
    
    def to_device(self, device):
        for layer in self.layers:
            layer.to_device(device)
    
    def train_mode(self):
        for layer in self.layers:
            layer.train_mode()
    
    def eval_mode(self):
        for layer in self.layers:
            layer.eval_mode()    
    
    def forward(self, x):
        for layer in self.layers:
            x = layer.forward(x)
        return x
    
    def loss(self, outputs, targets):
        return self.loss_fn.forward(outputs, targets)
    
    def __repr__(self):
        strs = ["Feedorward network with %d layers:" % (len(self.layers),)]
        for layer in self.layers:
            strs.append(repr(layer))
        return '\n'.join(strs)

# %%
from sklearn import datasets

iris = datasets.load_iris()
IrisX = iris.data.astype(np.float32)
IrisX = (IrisX - IrisX.mean(axis=0, keepdims=True)) / IrisX.std(axis=0, keepdims=True)
IrisY = iris.target

IrisX = torch.from_numpy(IrisX)
IrisY = torch.from_numpy(IrisY)

# %%
def GD(model, x, y, alpha=1e-4, max_iters=1000000, tolerance=1e-6, device='cpu'):
    """Simple batch gradient descent"""
    x = x.to(device)
    y = y.to(device)
    model.to_device(device)
    try:
        old_loss = np.inf
        model.train_mode()
        tstart = time.time()
        for i in xrange(max_iters):
            outputs = model.forward(x)
            loss = model.loss(outputs, y)

            loss.backward()
            
            # this disables autograd mechanism and allows us to 
            with torch.torch.no_grad():
                for _, p in model.parameters:
                    p -= p.grad * alpha
                    # Zero gradients for the next iteration
                    p.grad.zero_()

            loss = loss.item()
            if old_loss < loss:
                print "Iter: %d, loss increased!" % (i,)
            if (old_loss - loss) < tolerance:
                print "Tolerance level reached. Exiting."
                break
            if i % 1000 == 0:
                _, predictions = outputs.data.max(dim=1)
                err_rate = 100.0 * (predictions != y.data).sum() / outputs.size(0)
                print "Iteration {0: >6} | loss {1: >5.2f} | err rate  {2: >5.2f}% | steps/s {3: >5.2f}" \
                      .format(i, loss, err_rate, (1000 if i else 1) / (time.time() - tstart))
                tstart = time.time()
            old_loss = loss
    except KeyboardInterrupt:
        pass

# %%
model = FeedforwardNet(
    [AffineLayer(4, 10),
     TanhLayer(),
     AffineLayer(10, 3),
     SoftMaxLayer(),
    ])


# Initialize parameters
with torch.torch.no_grad():
    for n, p in model.parameters:
        if n == 'W':
            # p.data.normal_(0, 0.05)
            p.uniform_(-0.1, 0.1)
        elif n == 'b':
            p.zero_()
        else:
            raise ValueError('Unknown parameter name "%s"' % p.name)

# Train
# Iris is so small, that trainingon CPU is faster!
GD(model, IrisX, IrisY, alpha=1e-1, tolerance=1e-7, device='cpu')
# Out:
# /usr/local/lib/python2.7/dist-packages/torch/nn/functional.py:995: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Iteration      0 | loss  1.10 | err rate  78.00% | steps/s 17.64
# Iteration   1000 | loss  0.06 | err rate   2.00% | steps/s 1770.38
# Iteration   2000 | loss  0.04 | err rate   2.00% | steps/s 1839.48
# Iteration   3000 | loss  0.04 | err rate   1.00% | steps/s 1789.72
# Iteration   4000 | loss  0.04 | err rate   1.00% | steps/s 1813.36
# Iteration   5000 | loss  0.04 | err rate   1.00% | steps/s 1815.52
# Iteration   6000 | loss  0.04 | err rate   1.00% | steps/s 1868.80
# Iteration   7000 | loss  0.04 | err rate   1.00% | steps/s 1868.90
# Iteration   8000 | loss  0.04 | err rate   1.00% | steps/s 1791.16
# Iteration   9000 | loss  0.04 | err rate   1.00% | steps/s 1839.01
# Iteration  10000 | loss  0.04 | err rate   1.00% | steps/s 1859.94
# Iteration  11000 | loss  0.04 | err rate   1.00% | steps/s 1837.47
# Iteration  12000 | loss  0.04 | err rate   1.00% | steps/s 1848.45
# Iteration  13000 | loss  0.04 | err rate   1.00% | steps/s 1871.92
# Iteration  14000 | loss  0.04 | err rate   1.00% | steps/s 1896.13
# Iteration  15000 | loss  0.04 | err rate   1.00% | steps/s 1847.47
# Iteration  16000 | loss  0.04 | err rate   1.00% | steps/s 1825.22
# Iteration  17000 | loss  0.04 | err rate   1.00% | steps/s 1864.74
# Iteration  18000 | loss  0.04 | err rate   1.00% | steps/s 1849.24
# Iteration  19000 | loss  0.03 | err rate   1.00% | steps/s 1864.25
# Iteration  20000 | loss  0.03 | err rate   1.00% | steps/s 1835.82
# Iteration  21000 | loss  0.03 | err rate   1.00% | steps/s 1860.52
# Iteration  22000 | loss  0.03 | err rate   1.00% | steps/s 1848.35
# Iteration  23000 | loss  0.03 | err rate   1.00% | steps/s 1857.77
# Iteration  24000 | loss  0.03 | err rate   1.00% | steps/s 1837.48
# Iteration  25000 | loss  0.03 | err rate   1.00% | steps/s 1873.38
# Iteration  26000 | loss  0.03 | err rate   1.00% | steps/s 1852.37
# Iteration  27000 | loss  0.03 | err rate   1.00% | steps/s 1852.91
# Iteration  28000 | loss  0.03 | err rate   1.00% | steps/s 1846.21
# Iteration  29000 | loss  0.03 | err rate   1.00% | steps/s 1859.64
# Iteration  30000 | loss  0.03 | err rate   1.00% | steps/s 1831.51
# Iteration  31000 | loss  0.03 | err rate   1.00% | steps/s 1872.09
# Iteration  32000 | loss  0.02 | err rate   1.00% | steps/s 1868.53
# Iteration  33000 | loss  0.02 | err rate   1.00% | steps/s 1865.67
# Iteration  34000 | loss  0.02 | err rate   1.00% | steps/s 1860.25
# Iteration  35000 | loss  0.02 | err rate   1.00% | steps/s 1832.16
# Iteration  36000 | loss  0.02 | err rate   1.00% | steps/s 1871.89
# Iteration  37000 | loss  0.02 | err rate   1.00% | steps/s 1872.25
# Iteration  38000 | loss  0.02 | err rate   1.00% | steps/s 1880.97
# Iteration  39000 | loss  0.02 | err rate   1.00% | steps/s 1813.27
# Iteration  40000 | loss  0.02 | err rate   1.00% | steps/s 1852.47
# Iteration  41000 | loss  0.02 | err rate   0.00% | steps/s 1807.15
# Iteration  42000 | loss  0.02 | err rate   0.00% | steps/s 1849.93
# Iteration  43000 | loss  0.01 | err rate   0.00% | steps/s 1836.24
# Iteration  44000 | loss  0.01 | err rate   0.00% | steps/s 1892.83
# Iteration  45000 | loss  0.01 | err rate   0.00% | steps/s 1842.66
# Iteration  46000 | loss  0.01 | err rate   0.00% | steps/s 1873.43
# Iteration  47000 | loss  0.01 | err rate   0.00% | steps/s 1826.23
# Iteration  48000 | loss  0.01 | err rate   0.00% | steps/s 1868.65
# Iteration  49000 | loss  0.01 | err rate   0.00% | steps/s 1853.32
# Iteration  50000 | loss  0.01 | err rate   0.00% | steps/s 1874.91
# Iteration  51000 | loss  0.01 | err rate   0.00% | steps/s 1809.30
# Iteration  52000 | loss  0.01 | err rate   0.00% | steps/s 1823.07
# Iteration  53000 | loss  0.01 | err rate   0.00% | steps/s 1868.13
# Iteration  54000 | loss  0.01 | err rate   0.00% | steps/s 1841.31
# Iteration  55000 | loss  0.01 | err rate   0.00% | steps/s 1860.92
# Iteration  56000 | loss  0.01 | err rate   0.00% | steps/s 1839.99
# Iteration  57000 | loss  0.01 | err rate   0.00% | steps/s 1857.66
# Iteration  58000 | loss  0.01 | err rate   0.00% | steps/s 1802.95
# Iteration  59000 | loss  0.01 | err rate   0.00% | steps/s 1856.94
# Iteration  60000 | loss  0.01 | err rate   0.00% | steps/s 1839.42
# Iteration  61000 | loss  0.01 | err rate   0.00% | steps/s 1829.64
# Iteration  62000 | loss  0.00 | err rate   0.00% | steps/s 1855.47
# Iteration  63000 | loss  0.00 | err rate   0.00% | steps/s 1900.99
# Iteration  64000 | loss  0.00 | err rate   0.00% | steps/s 1832.88
# Iteration  65000 | loss  0.00 | err rate   0.00% | steps/s 1828.60
# Iteration  66000 | loss  0.00 | err rate   0.00% | steps/s 1838.46
# Iteration  67000 | loss  0.00 | err rate   0.00% | steps/s 1852.33
# Iteration  68000 | loss  0.00 | err rate   0.00% | steps/s 1883.93
# Iteration  69000 | loss  0.00 | err rate   0.00% | steps/s 1868.28
# Iteration  70000 | loss  0.00 | err rate   0.00% | steps/s 1855.90
# Iteration  71000 | loss  0.00 | err rate   0.00% | steps/s 1816.99
# Iteration  72000 | loss  0.00 | err rate   0.00% | steps/s 1868.17
# Iteration  73000 | loss  0.00 | err rate   0.00% | steps/s 1848.60
# Iteration  74000 | loss  0.00 | err rate   0.00% | steps/s 1865.40
# Tolerance level reached. Exiting.

# %% [markdown]
# # Starter code for MNIST and SGD scaffolding

# %%
import os
import torch
import torchvision


batch_size = 128
data_path = './data'

transform = torchvision.transforms.Compose(
    [torchvision.transforms.ToTensor(),
     torchvision.transforms.Normalize((0.1307,), (0.3081,)),
    ])

_test = torchvision.datasets.MNIST(
    data_path, train=False, download=True, transform=transform)

# Load training data, split into train and valid sets
_train = torchvision.datasets.MNIST(
    data_path, train=True, download=True, transform=transform)
_train.train_data = _train.train_data[:50000]
_train.train_labels = _train.train_labels[:50000]

_valid = torchvision.datasets.MNIST(
    data_path, train=True, download=True, transform=transform)
_valid.train_data = _valid.train_data[50000:]
_valid.train_labels = _valid.train_labels[50000:]

mnist_loaders = {
    'train': torch.utils.data.DataLoader(
        _train, batch_size=batch_size, shuffle=True,
        pin_memory=True, num_workers=10),
    'valid': torch.utils.data.DataLoader(
        _valid, batch_size=batch_size, shuffle=False),
    'test': torch.utils.data.DataLoader(
        _test, batch_size=batch_size, shuffle=False)}
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Processing...
# Done!

# %% [markdown]
# # Problem 1: Stochastic Gradient Descent [3p]
# Implement the following additions to the SGD code provided below (in task 2):
#   1. **[1p]** momentum
#   2. **[1p]** learning rate schedule
#   3. **[1p]** weight decay, in which we additionally minimize for each weight matrix (but typically not the bias) the sum of its elements squared. One way to implement it is to use function `model.parameters` and select all parameters whose names are "`W`" and not "`b`".

# %% [markdown]
# # Problem 2: Tuning the Network for MNIST [4p]
#
# Tune the following network to reach **validation error rate below 1.9%**.
# This should result in a **test error rate below 2%**. To
# tune the network you will need to:
# 1. Choose the number of layers (more than 1, less than 5);
# 2. Choose the number of neurons in each layer (more than 100,
#     less than 5000);
# 3. Pick proper weight initialization;
# 4. Pick proper learning rate schedule (need to decay over time,
#     good range to check on MNIST is about 1e-2 ... 1e-1 at the beginning and
#     half of that after 10000 batches);
# 5. Pick a momentum constant (probably a constant one will be OK).

# %%
def compute_error_rate(model, data_loader, device='cpu'):
    model.eval_mode()
    num_errs = 0.0
    num_examples = 0
    # we don't need gradient during eval!
    with torch.no_grad():
        for x, y in data_loader:
            x = x.to(device).view(x.size(0), -1)
            y = y.to(device)
            outputs = model.forward(x)
            _, predictions = outputs.data.max(dim=1)
            num_errs += (predictions != y.data).sum().item()
            num_examples += x.size(0)
    return 100.0 * num_errs / num_examples

def SGD(model, data_loaders, alpha=1e-4, num_epochs=1, patience_expansion=1.5,
        log_every=100, device='cpu',learning_rate_c=0.85,momentum_epsilon=0.0,
        lambda_=0.05):
    model.to_device(device)
    #
    # TODO: Initialize momentum variables
    # Hint: You need one velocity matrix for each parameter
    #
    velocities = [torch.zeros_like(p).to(device) for _, p in model.parameters]

    iter_ = 0
    epoch = 0
    best_params = None
    best_val_err = np.inf
    history = {'train_losses': [], 'train_errs': [], 'val_errs': []}
    print('Training the model!')
    print('Interrupt at any time to evaluate the best validation model so far.')
    try:
        tstart = time.time()
        siter = iter_
        while epoch < num_epochs:
            model.train_mode()
            epoch += 1
            for x, y in data_loaders['train']:
                x = x.to(device).view(x.size(0), -1)
                y = y.to(device)
                iter_ += 1
                out = model.forward(x)
                loss = model.loss(out, y)
                loss.backward()
                _, predictions = out.max(dim=1)
                err_rate = 100.0 * (predictions != y).sum().item() / out.size(0)

                history['train_losses'].append(loss.item())
                history['train_errs'].append(err_rate)
                
                # disable gradient computations - we do not want torch to
                # backpropagate through the gradient application!
                with torch.no_grad():
                    for (name, p), v in zip(model.parameters, velocities):
                        if name == 'W':
                            p.grad += lambda_ * p
                        #
                        # TODO: Implement weight decay addition to gradients
                        # p.grad += TODO
                        # 

                        #
                        # TODO: Update learning rate
                        # Hint: Use the iteration counter i
                        if iter_ == 10000:
                            alpha *= 0.5

                        #
                        # TODO: Set the momentum constant 
                        epsilon = momentum_epsilon

                        #
                        # TODO: Implement velocity update in momentum
                        # lease make sure to modify the contents of v, not the v pointer!!!
                        v = epsilon * v

                        #
                        # TODO: Set a more sensible learning rule here,
                        #       using your learning rate schedule and momentum
                        # 
                        p -= (alpha * p.grad + v) * learning_rate_c
                        # Zero gradients for the next iteration
                        p.grad.zero_()

                if iter_ % log_every == 0:
                    num_iter = iter_ - siter + 1
                    print "Minibatch {0: >6}  | loss {1: >5.2f} | err rate {2: >5.2f}%, steps/s {3: >5.2f}" \
                          .format(iter_, loss.item(), err_rate, num_iter / (time.time() - tstart))
                    tstart = time.time()
                           
            
            val_err_rate = compute_error_rate(model, data_loaders['valid'], device)
            history['val_errs'].append((iter_, val_err_rate))
            
            if val_err_rate < best_val_err:
                # Adjust num of epochs
                num_epochs = int(np.maximum(num_epochs, epoch * patience_expansion + 1))
                best_epoch = epoch
                best_val_err = val_err_rate
                best_params = [p.detach().cpu() for (_, p) in model.parameters]
            m = "After epoch {0: >2} | valid err rate: {1: >5.2f}% | doing {2: >3} epochs" \
                .format(epoch, val_err_rate, num_epochs)
            print '{0}\n{1}\n{0}'.format('-' * len(m), m)

    except KeyboardInterrupt:
        pass
    if best_params is not None:
        print "\nLoading best params on validation set (epoch %d)\n" %(best_epoch)
        model.parameters = best_params
    plot_history(history)

def plot_history(history):
    figsize(16, 4)
    subplot(1,2,1)
    train_loss = np.array(history['train_losses'])
    semilogy(np.arange(train_loss.shape[0]), train_loss, label='batch train loss')
    legend()
        
    subplot(1,2,2)
    train_errs = np.array(history['train_errs'])
    plot(np.arange(train_errs.shape[0]), train_errs, label='batch train error rate')
    val_errs = np.array(history['val_errs'])
    plot(val_errs[:,0], val_errs[:,1], label='validation error rate', color='r')
    ylim(0,20)
    legend()

# %%
#
# TODO: Pick a network architecture here.
#       The one below is just softmax regression.
#

model = FeedforwardNet(
    [
    AffineLayer(784, 2000),
    TanhLayer(),
    AffineLayer(2000,6000),
    TanhLayer(),
    AffineLayer(6000, 500),
    TanhLayer(),
    AffineLayer(500, 20),
    SoftMaxLayer()
    ])


with torch.no_grad():
    # Initialize parameters
    for name, p in model.parameters:
        if name == 'W':
#             p.normal_(0, 0.05)
            p.data.uniform_(-1.0/np.sqrt(2000.), 1.0/np.sqrt(2000.))
        elif name == 'b':
            p.zero_()
        else:
            raise ValueError('Unknown parameter name "%s"' % p.name)

# On GPU enabled devices set device='cuda' else set device='cpu'
SGD(model, mnist_loaders, alpha=0.089, device='cuda', momentum_epsilon=0.9,lambda_=0.0007)

print "Test error rate: %.2f%%" % compute_error_rate(model, mnist_loaders['test'])
# Out:
# Training the model!
# Interrupt at any time to evaluate the best validation model so far.
# Minibatch    100  | loss  0.38 | err rate 10.94%, steps/s 25.62
# Minibatch    200  | loss  0.32 | err rate  7.81%, steps/s 86.65
# Minibatch    300  | loss  0.22 | err rate  7.03%, steps/s 128.92
# ----------------------------------------------------------
# After epoch  1 | valid err rate:  7.21% | doing   2 epochs
# ----------------------------------------------------------
# Minibatch    400  | loss  0.23 | err rate  8.59%, steps/s 88.33
# Minibatch    500  | loss  0.14 | err rate  2.34%, steps/s 217.16
# Minibatch    600  | loss  0.26 | err rate  6.25%, steps/s 258.40
# Minibatch    700  | loss  0.25 | err rate  5.47%, steps/s 298.14
# ----------------------------------------------------------
# After epoch  2 | valid err rate:  5.63% | doing   4 epochs
# ----------------------------------------------------------
# Minibatch    800  | loss  0.23 | err rate  6.25%, steps/s 176.31
# Minibatch    900  | loss  0.21 | err rate  3.91%, steps/s 389.01
# Minibatch   1000  | loss  0.12 | err rate  3.91%, steps/s 433.62
# Minibatch   1100  | loss  0.09 | err rate  2.34%, steps/s 476.95
# ----------------------------------------------------------
# After epoch  3 | valid err rate:  4.95% | doing   5 epochs
# ----------------------------------------------------------
# Minibatch   1200  | loss  0.12 | err rate  3.91%, steps/s 265.78
# Minibatch   1300  | loss  0.12 | err rate  3.12%, steps/s 563.33
# Minibatch   1400  | loss  0.08 | err rate  3.12%, steps/s 600.31
# Minibatch   1500  | loss  0.24 | err rate  8.59%, steps/s 653.65
# ----------------------------------------------------------
# After epoch  4 | valid err rate:  3.80% | doing   7 epochs
# ----------------------------------------------------------
# Minibatch   1600  | loss  0.10 | err rate  1.56%, steps/s 355.04
# Minibatch   1700  | loss  0.04 | err rate  0.00%, steps/s 726.96
# Minibatch   1800  | loss  0.11 | err rate  5.47%, steps/s 778.28
# Minibatch   1900  | loss  0.22 | err rate  5.47%, steps/s 824.26
# ----------------------------------------------------------
# After epoch  5 | valid err rate:  3.82% | doing   7 epochs
# ----------------------------------------------------------
# Minibatch   2000  | loss  0.22 | err rate  7.03%, steps/s 448.46
# Minibatch   2100  | loss  0.09 | err rate  2.34%, steps/s 907.60
# Minibatch   2200  | loss  0.11 | err rate  3.12%, steps/s 951.30
# Minibatch   2300  | loss  0.20 | err rate  7.81%, steps/s 1001.32
# ----------------------------------------------------------
# After epoch  6 | valid err rate:  3.39% | doing  10 epochs
# ----------------------------------------------------------
# Minibatch   2400  | loss  0.04 | err rate  0.00%, steps/s 533.14
# Minibatch   2500  | loss  0.08 | err rate  3.12%, steps/s 1071.13
# Minibatch   2600  | loss  0.11 | err rate  3.91%, steps/s 1115.32
# Minibatch   2700  | loss  0.11 | err rate  2.34%, steps/s 1159.24
# ----------------------------------------------------------
# After epoch  7 | valid err rate:  3.19% | doing  11 epochs
# ----------------------------------------------------------
# Minibatch   2800  | loss  0.11 | err rate  3.91%, steps/s 621.98
# Minibatch   2900  | loss  0.05 | err rate  1.56%, steps/s 1249.19
# Minibatch   3000  | loss  0.17 | err rate  3.91%, steps/s 1287.46
# Minibatch   3100  | loss  0.08 | err rate  3.12%, steps/s 1348.18
# ----------------------------------------------------------
# After epoch  8 | valid err rate:  2.89% | doing  13 epochs
# ----------------------------------------------------------
# Minibatch   3200  | loss  0.06 | err rate  0.78%, steps/s 709.49
# Minibatch   3300  | loss  0.07 | err rate  1.56%, steps/s 1426.26
# Minibatch   3400  | loss  0.05 | err rate  0.78%, steps/s 1477.80
# Minibatch   3500  | loss  0.07 | err rate  2.34%, steps/s 1513.75
# ----------------------------------------------------------
# After epoch  9 | valid err rate:  3.03% | doing  13 epochs
# ----------------------------------------------------------
# Minibatch   3600  | loss  0.06 | err rate  1.56%, steps/s 809.85
# Minibatch   3700  | loss  0.04 | err rate  0.78%, steps/s 1586.56
# Minibatch   3800  | loss  0.07 | err rate  2.34%, steps/s 1639.97
# Minibatch   3900  | loss  0.08 | err rate  1.56%, steps/s 1708.99
# ----------------------------------------------------------
# After epoch 10 | valid err rate:  2.56% | doing  16 epochs
# ----------------------------------------------------------
# Minibatch   4000  | loss  0.08 | err rate  2.34%, steps/s 881.52
# Minibatch   4100  | loss  0.05 | err rate  1.56%, steps/s 1775.75
# Minibatch   4200  | loss  0.06 | err rate  2.34%, steps/s 1804.32
# Minibatch   4300  | loss  0.05 | err rate  0.78%, steps/s 1942.30
# ----------------------------------------------------------
# After epoch 11 | valid err rate:  2.43% | doing  17 epochs
# ----------------------------------------------------------
# Minibatch   4400  | loss  0.07 | err rate  1.56%, steps/s 962.43
# Minibatch   4500  | loss  0.03 | err rate  0.78%, steps/s 1898.51
# Minibatch   4600  | loss  0.07 | err rate  2.34%, steps/s 1991.76
# ----------------------------------------------------------
# After epoch 12 | valid err rate:  2.53% | doing  17 epochs
# ----------------------------------------------------------
# Minibatch   4700  | loss  0.04 | err rate  0.78%, steps/s 1050.10
# Minibatch   4800  | loss  0.02 | err rate  0.00%, steps/s 2084.07
# Minibatch   4900  | loss  0.08 | err rate  2.34%, steps/s 2120.39
# Minibatch   5000  | loss  0.11 | err rate  3.12%, steps/s 2127.46
# ----------------------------------------------------------
# After epoch 13 | valid err rate:  2.24% | doing  20 epochs
# ----------------------------------------------------------
# Minibatch   5100  | loss  0.03 | err rate  0.00%, steps/s 1135.64
# Minibatch   5200  | loss  0.05 | err rate  2.34%, steps/s 2271.04
# Minibatch   5300  | loss  0.02 | err rate  0.00%, steps/s 2305.03
# Minibatch   5400  | loss  0.04 | err rate  0.00%, steps/s 2348.03
# ----------------------------------------------------------
# After epoch 14 | valid err rate:  2.40% | doing  20 epochs
# ----------------------------------------------------------
# Minibatch   5500  | loss  0.03 | err rate  0.00%, steps/s 1238.88
# Minibatch   5600  | loss  0.11 | err rate  3.91%, steps/s 2436.35
# Minibatch   5700  | loss  0.04 | err rate  0.78%, steps/s 2451.39
# Minibatch   5800  | loss  0.03 | err rate  0.00%, steps/s 2518.06
# ----------------------------------------------------------
# After epoch 15 | valid err rate:  2.50% | doing  20 epochs
# ----------------------------------------------------------
# Minibatch   5900  | loss  0.06 | err rate  0.78%, steps/s 1326.46
# Minibatch   6000  | loss  0.04 | err rate  0.78%, steps/s 2585.93
# Minibatch   6100  | loss  0.03 | err rate  0.78%, steps/s 2645.50
# Minibatch   6200  | loss  0.08 | err rate  3.12%, steps/s 2646.31
# ----------------------------------------------------------
# After epoch 16 | valid err rate:  2.32% | doing  20 epochs
# ----------------------------------------------------------
# Minibatch   6300  | loss  0.02 | err rate  0.00%, steps/s 1417.56
# Minibatch   6400  | loss  0.02 | err rate  0.78%, steps/s 2735.72
# Minibatch   6500  | loss  0.08 | err rate  1.56%, steps/s 2804.04
# Minibatch   6600  | loss  0.02 | err rate  0.00%, steps/s 2847.70
# ----------------------------------------------------------
# After epoch 17 | valid err rate:  2.31% | doing  20 epochs
# ----------------------------------------------------------
# Minibatch   6700  | loss  0.01 | err rate  0.00%, steps/s 1496.82
# Minibatch   6800  | loss  0.01 | err rate  0.00%, steps/s 2935.66
# Minibatch   6900  | loss  0.02 | err rate  0.00%, steps/s 2986.58
# Minibatch   7000  | loss  0.01 | err rate  0.00%, steps/s 3012.41
# ----------------------------------------------------------
# After epoch 18 | valid err rate:  2.40% | doing  20 epochs
# ----------------------------------------------------------
# Minibatch   7100  | loss  0.02 | err rate  0.00%, steps/s 1588.83
# Minibatch   7200  | loss  0.06 | err rate  1.56%, steps/s 3115.49
# Minibatch   7300  | loss  0.06 | err rate  2.34%, steps/s 3109.26
# Minibatch   7400  | loss  0.02 | err rate  0.78%, steps/s 3168.67
# ----------------------------------------------------------
# After epoch 19 | valid err rate:  2.09% | doing  29 epochs
# ----------------------------------------------------------
# Minibatch   7500  | loss  0.01 | err rate  0.00%, steps/s 1651.19
# Minibatch   7600  | loss  0.02 | err rate  0.78%, steps/s 3229.76
# Minibatch   7700  | loss  0.01 | err rate  0.00%, steps/s 3310.59
# Minibatch   7800  | loss  0.02 | err rate  0.78%, steps/s 3412.47
# ----------------------------------------------------------
# After epoch 20 | valid err rate:  2.10% | doing  29 epochs
# ----------------------------------------------------------
# Minibatch   7900  | loss  0.02 | err rate  0.00%, steps/s 1768.13
# Minibatch   8000  | loss  0.04 | err rate  0.78%, steps/s 3432.20
# Minibatch   8100  | loss  0.03 | err rate  0.78%, steps/s 3508.21
# Minibatch   8200  | loss  0.03 | err rate  0.00%, steps/s 3585.82
# ----------------------------------------------------------
# After epoch 21 | valid err rate:  2.21% | doing  29 epochs
# ----------------------------------------------------------
# Minibatch   8300  | loss  0.02 | err rate  0.78%, steps/s 1851.89
# Minibatch   8400  | loss  0.02 | err rate  0.00%, steps/s 3601.95
# Minibatch   8500  | loss  0.05 | err rate  1.56%, steps/s 3708.29
# Minibatch   8600  | loss  0.02 | err rate  0.00%, steps/s 3858.54
# ----------------------------------------------------------
# After epoch 22 | valid err rate:  1.92% | doing  34 epochs
# ----------------------------------------------------------
# Minibatch   8700  | loss  0.04 | err rate  2.34%, steps/s 1913.99
# Minibatch   8800  | loss  0.01 | err rate  0.00%, steps/s 3789.58
# Minibatch   8900  | loss  0.03 | err rate  0.78%, steps/s 3795.56
# ----------------------------------------------------------
# After epoch 23 | valid err rate:  1.95% | doing  34 epochs
# ----------------------------------------------------------
# Minibatch   9000  | loss  0.03 | err rate  0.78%, steps/s 2010.36
# Minibatch   9100  | loss  0.03 | err rate  0.78%, steps/s 3959.55
# Minibatch   9200  | loss  0.04 | err rate  0.78%, steps/s 3973.19
# Minibatch   9300  | loss  0.02 | err rate  0.00%, steps/s 3963.61
# ----------------------------------------------------------
# After epoch 24 | valid err rate:  1.92% | doing  34 epochs
# ----------------------------------------------------------
# Minibatch   9400  | loss  0.02 | err rate  0.00%, steps/s 2118.78
# Minibatch   9500  | loss  0.02 | err rate  0.00%, steps/s 4109.86
# Minibatch   9600  | loss  0.01 | err rate  0.00%, steps/s 4151.66
# Minibatch   9700  | loss  0.02 | err rate  0.00%, steps/s 4245.63
# ----------------------------------------------------------
# After epoch 25 | valid err rate:  2.12% | doing  34 epochs
# ----------------------------------------------------------
# Minibatch   9800  | loss  0.02 | err rate  1.56%, steps/s 2188.36
# Minibatch   9900  | loss  0.03 | err rate  0.78%, steps/s 4281.09
# Minibatch  10000  | loss  0.02 | err rate  0.00%, steps/s 4335.73
# Minibatch  10100  | loss  0.01 | err rate  0.00%, steps/s 4410.44
# ----------------------------------------------------------
# After epoch 26 | valid err rate:  2.10% | doing  34 epochs
# ----------------------------------------------------------
# Minibatch  10200  | loss  0.02 | err rate  0.00%, steps/s 2292.88
# Minibatch  10300  | loss  0.01 | err rate  0.00%, steps/s 4454.33
# Minibatch  10400  | loss  0.01 | err rate  0.00%, steps/s 4451.98
# Minibatch  10500  | loss  0.02 | err rate  0.00%, steps/s 4564.09
# ----------------------------------------------------------
# After epoch 27 | valid err rate:  1.98% | doing  34 epochs
# ----------------------------------------------------------
# Minibatch  10600  | loss  0.02 | err rate  0.00%, steps/s 2389.89
# Minibatch  10700  | loss  0.01 | err rate  0.00%, steps/s 4644.54
# Minibatch  10800  | loss  0.02 | err rate  0.00%, steps/s 4682.25
# Minibatch  10900  | loss  0.01 | err rate  0.00%, steps/s 4729.34
# ----------------------------------------------------------
# After epoch 28 | valid err rate:  1.94% | doing  34 epochs
# ----------------------------------------------------------
# Minibatch  11000  | loss  0.03 | err rate  0.78%, steps/s 2455.44
# Minibatch  11100  | loss  0.03 | err rate  0.00%, steps/s 4821.32
# Minibatch  11200  | loss  0.03 | err rate  0.78%, steps/s 4874.35
# Minibatch  11300  | loss  0.02 | err rate  0.00%, steps/s 4853.56
# ----------------------------------------------------------
# After epoch 29 | valid err rate:  1.87% | doing  44 epochs
# ----------------------------------------------------------
# Minibatch  11400  | loss  0.01 | err rate  0.00%, steps/s 2548.95
# Minibatch  11500  | loss  0.05 | err rate  0.78%, steps/s 4985.39
# Minibatch  11600  | loss  0.01 | err rate  0.00%, steps/s 5015.80
# Minibatch  11700  | loss  0.02 | err rate  0.00%, steps/s 5023.83
# ----------------------------------------------------------
# After epoch 30 | valid err rate:  1.85% | doing  46 epochs
# ----------------------------------------------------------
# Minibatch  11800  | loss  0.02 | err rate  0.00%, steps/s 2634.18
# Minibatch  11900  | loss  0.02 | err rate  0.78%, steps/s 5162.01
# Minibatch  12000  | loss  0.01 | err rate  0.00%, steps/s 5220.05
# Minibatch  12100  | loss  0.02 | err rate  0.00%, steps/s 5202.47
# ----------------------------------------------------------
# After epoch 31 | valid err rate:  1.85% | doing  46 epochs
# ----------------------------------------------------------
# Minibatch  12200  | loss  0.02 | err rate  0.00%, steps/s 2736.49
# Minibatch  12300  | loss  0.08 | err rate  1.56%, steps/s 5406.28
# Minibatch  12400  | loss  0.01 | err rate  0.00%, steps/s 5346.37
# Minibatch  12500  | loss  0.01 | err rate  0.00%, steps/s 5528.36
# ----------------------------------------------------------
# After epoch 32 | valid err rate:  1.85% | doing  46 epochs
# ----------------------------------------------------------
# Minibatch  12600  | loss  0.01 | err rate  0.00%, steps/s 2822.41
# Minibatch  12700  | loss  0.01 | err rate  0.00%, steps/s 5535.83
# Minibatch  12800  | loss  0.02 | err rate  0.78%, steps/s 5482.21
# Minibatch  12900  | loss  0.01 | err rate  0.00%, steps/s 5868.32
# ----------------------------------------------------------
# After epoch 33 | valid err rate:  1.84% | doing  50 epochs
# ----------------------------------------------------------
# Minibatch  13000  | loss  0.01 | err rate  0.00%, steps/s 2865.20
# Minibatch  13100  | loss  0.01 | err rate  0.00%, steps/s 5718.11
# Minibatch  13200  | loss  0.01 | err rate  0.00%, steps/s 5712.86
# ----------------------------------------------------------
# After epoch 34 | valid err rate:  1.83% | doing  52 epochs
# ----------------------------------------------------------
# Minibatch  13300  | loss  0.03 | err rate  0.78%, steps/s 3012.29
# Minibatch  13400  | loss  0.01 | err rate  0.00%, steps/s 5715.04
# Minibatch  13500  | loss  0.01 | err rate  0.00%, steps/s 5926.41
# Minibatch  13600  | loss  0.02 | err rate  0.78%, steps/s 5877.26
# ----------------------------------------------------------
# After epoch 35 | valid err rate:  1.83% | doing  52 epochs
# ----------------------------------------------------------
# Minibatch  13700  | loss  0.02 | err rate  0.00%, steps/s 3048.67
# Minibatch  13800  | loss  0.04 | err rate  0.78%, steps/s 6022.88
# Minibatch  13900  | loss  0.02 | err rate  0.78%, steps/s 6073.33
# Minibatch  14000  | loss  0.01 | err rate  0.00%, steps/s 6094.00
# ----------------------------------------------------------
# After epoch 36 | valid err rate:  1.84% | doing  52 epochs
# ----------------------------------------------------------
# Minibatch  14100  | loss  0.02 | err rate  0.00%, steps/s 3159.62
# Minibatch  14200  | loss  0.01 | err rate  0.00%, steps/s 6205.09
# Minibatch  14300  | loss  0.01 | err rate  0.00%, steps/s 6155.82
# Minibatch  14400  | loss  0.12 | err rate  2.34%, steps/s 6191.42
# ----------------------------------------------------------
# After epoch 37 | valid err rate:  1.84% | doing  52 epochs
# ----------------------------------------------------------
# Minibatch  14500  | loss  0.02 | err rate  0.00%, steps/s 3247.01
# Minibatch  14600  | loss  0.01 | err rate  0.00%, steps/s 6269.55
# Minibatch  14700  | loss  0.02 | err rate  0.00%, steps/s 6462.83
# Minibatch  14800  | loss  0.05 | err rate  0.78%, steps/s 6436.93
# ----------------------------------------------------------
# After epoch 38 | valid err rate:  1.85% | doing  52 epochs
# ----------------------------------------------------------
# Minibatch  14900  | loss  0.01 | err rate  0.00%, steps/s 3332.85
# Minibatch  15000  | loss  0.02 | err rate  0.00%, steps/s 6551.33
# Minibatch  15100  | loss  0.02 | err rate  0.00%, steps/s 6515.20
# Minibatch  15200  | loss  0.01 | err rate  0.00%, steps/s 6574.69
# ----------------------------------------------------------
# After epoch 39 | valid err rate:  1.86% | doing  52 epochs
# ----------------------------------------------------------
# Minibatch  15300  | loss  0.02 | err rate  0.78%, steps/s 3407.54
# Minibatch  15400  | loss  0.02 | err rate  0.78%, steps/s 6578.46
# Minibatch  15500  | loss  0.02 | err rate  0.78%, steps/s 6729.23
# Minibatch  15600  | loss  0.01 | err rate  0.00%, steps/s 6689.20
# ----------------------------------------------------------
# After epoch 40 | valid err rate:  1.85% | doing  52 epochs
# ----------------------------------------------------------
# Minibatch  15700  | loss  0.01 | err rate  0.00%, steps/s 3515.41
# Minibatch  15800  | loss  0.02 | err rate  0.00%, steps/s 6893.70
# Minibatch  15900  | loss  0.01 | err rate  0.00%, steps/s 6941.26
# Minibatch  16000  | loss  0.01 | err rate  0.78%, steps/s 6957.57
# ----------------------------------------------------------
# After epoch 41 | valid err rate:  1.85% | doing  52 epochs
# ----------------------------------------------------------
# Minibatch  16100  | loss  0.02 | err rate  0.00%, steps/s 3592.96
# Minibatch  16200  | loss  0.01 | err rate  0.00%, steps/s 7001.52
# Minibatch  16300  | loss  0.01 | err rate  0.00%, steps/s 7146.10
# Process Process-2399:
# Process Process-2400:
# Process Process-2398:
# Process Process-2392:
# Process Process-2391:
# Process Process-2393:
# Process Process-2394:
# Process Process-2397:
# Traceback (most recent call last):
# Process Process-2396:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process Process-2395:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
# Traceback (most recent call last):
# Traceback (most recent call last):
#     self.run()
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#     self.run()
#     self.run()
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python2.7/dist-packages/torch/utils/data/dataloader.py", line 106, in _worker_loop
#   File "/usr/local/lib/python2.7/dist-packages/torch/utils/data/dataloader.py", line 96, in _worker_loop
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self.run()
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python2.7/dist-packages/torch/utils/data/dataloader.py", line 106, in _worker_loop
#   File "/usr/local/lib/python2.7/dist-packages/torch/utils/data/dataloader.py", line 96, in _worker_loop
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/usr/local/lib/python2.7/dist-packages/torch/utils/data/dataloader.py", line 106, in _worker_loop
#     r = index_queue.get(timeout=MANAGER_STATUS_CHECK_INTERVAL)
#   File "/usr/local/lib/python2.7/dist-packages/torch/utils/data/dataloader.py", line 96, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
#     samples = collate_fn([dataset[i] for i in batch_indices])
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/usr/lib/python2.7/multiprocessing/queues.py", line 131, in get
#   File "/usr/local/lib/python2.7/dist-packages/torch/utils/data/dataloader.py", line 96, in _worker_loop
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python2.7/dist-packages/torch/utils/data/dataloader.py", line 106, in _worker_loop
#     r = index_queue.get(timeout=MANAGER_STATUS_CHECK_INTERVAL)
#   File "/usr/local/lib/python2.7/dist-packages/torchvision/datasets/mnist.py", line 77, in __getitem__
#     r = index_queue.get(timeout=MANAGER_STATUS_CHECK_INTERVAL)
#     samples = collate_fn([dataset[i] for i in batch_indices])
# Loading best params on validation set (epoch 34)
#     if not self._poll(timeout):
#   File "/usr/local/lib/python2.7/dist-packages/torchvision/datasets/mnist.py", line 77, in __getitem__
#     r = index_queue.get(timeout=MANAGER_STATUS_CHECK_INTERVAL)
#   File "/usr/local/lib/python2.7/dist-packages/torch/utils/data/dataloader.py", line 106, in _worker_loop
#   File "/usr/lib/python2.7/multiprocessing/queues.py", line 131, in get
#   File "/usr/local/lib/python2.7/dist-packages/torch/utils/data/dataloader.py", line 96, in _worker_loop
#   File "/usr/lib/python2.7/multiprocessing/queues.py", line 131, in get
#     img = self.transform(img)
#     samples = collate_fn([dataset[i] for i in batch_indices])
# KeyboardInterrupt
#     img = self.transform(img)
#   File "/usr/lib/python2.7/multiprocessing/queues.py", line 131, in get
#     samples = collate_fn([dataset[i] for i in batch_indices])
#     r = index_queue.get(timeout=MANAGER_STATUS_CHECK_INTERVAL)
#     if not self._poll(timeout):
#   File "/usr/local/lib/python2.7/dist-packages/torchvision/datasets/mnist.py", line 77, in __getitem__
#   File "/usr/local/lib/python2.7/dist-packages/torchvision/datasets/mnist.py", line 74, in __getitem__
# KeyboardInterrupt
#   File "/usr/local/lib/python2.7/dist-packages/torchvision/datasets/mnist.py", line 77, in __getitem__
#   File "/usr/local/lib/python2.7/dist-packages/torchvision/transforms/transforms.py", line 49, in __call__
#     if not self._poll(timeout):
#   File "/usr/local/lib/python2.7/dist-packages/torchvision/transforms/transforms.py", line 49, in __call__
#     if not self._poll(timeout):
#   File "/usr/lib/python2.7/multiprocessing/queues.py", line 131, in get
# KeyboardInterrupt
#     img = self.transform(img)
#     img = t(img)
#     img = Image.fromarray(img.numpy(), mode='L')
# KeyboardInterrupt
#     if not self._poll(timeout):
#     img = t(img)
#     img = self.transform(img)
#   File "/usr/local/lib/python2.7/dist-packages/torchvision/transforms/transforms.py", line 49, in __call__
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2217, in fromarray
# KeyboardInterrupt
#   File "/usr/local/lib/python2.7/dist-packages/torchvision/transforms/transforms.py", line 76, in __call__
#   File "/usr/local/lib/python2.7/dist-packages/torchvision/transforms/transforms.py", line 143, in __call__
#     return F.to_tensor(pic)
#     return F.normalize(tensor, self.mean, self.std)
#     ne = data[6:8]
#   File "/usr/local/lib/python2.7/dist-packages/torchvision/transforms/transforms.py", line 49, in __call__
#     img = t(img)
#   File "/usr/local/lib/python2.7/dist-packages/torchvision/transforms/functional.py", line 83, in to_tensor
#   File "/usr/local/lib/python2.7/dist-packages/torchvision/transforms/functional.py", line 168, in normalize
#   File "/usr/local/lib/python2.7/dist-packages/torchvision/transforms/transforms.py", line 76, in __call__
#     img = t(img)
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2160, in frombuffer
#     return img.float().div(255)
#     t.sub_(m).div_(s)
#   File "/usr/local/lib/python2.7/dist-packages/torchvision/transforms/transforms.py", line 143, in __call__
#     return F.to_tensor(pic)
#     """
# KeyboardInterrupt
# KeyboardInterrupt
#     return F.normalize(tensor, self.mean, self.std)
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2057, in new
#   File "/usr/local/lib/python2.7/dist-packages/torchvision/transforms/functional.py", line 83, in to_tensor
#     'The image has no channel "{}"'.format(channel))
#     return img.float().div(255)
#   File "/usr/local/lib/python2.7/dist-packages/torchvision/transforms/functional.py", line 167, in normalize
#   File "/usr/local/lib/python2.7/dist-packages/PIL/_util.py", line 4, in isStringType
# KeyboardInterrupt
#     py3 = sys.version_info.major >= 3
#     for t, m, s in zip(tensor, mean, std):
# KeyboardInterrupt
#   File "/usr/local/lib/python2.7/dist-packages/torch/tensor.py", line 382, in <lambda>
#     return iter(imap(lambda i: self[i], range(self.size(0))))
# KeyboardInterrupt
# Test error rate: 1.92%

# %% [markdown]
# # Problem 3: Dropout [2p]
#
# Implement a **dropout** layer and try to train a
# network getting below 1.5% test error rates with dropout. The best
# results with dropout are below 1%!
#
# Remember to turn off dropout during testing, using `model.train_mode()` and `model.eval_mode()`!
#
# Hint: Use [torch.nn.functional.dropout](http://pytorch.org/docs/master/nn.html#torch.nn.functional.dropout).
#
# Details: http://arxiv.org/pdf/1207.0580.pdf.

# %% [markdown]
# # Problem 4: Data Augmentation [1p]
#
# Apply data augmentation methods (e.g. rotations, noise, crops) when training networks on MNIST, to significantly reduce test error rate for your network. You can use functions from the [torchvision.transforms](http://pytorch.org/docs/master/torchvision/transforms.html) module.

# %% [markdown]
# # Problem 5: Batch Normalization [1p]
#
# *Covariate shift* is a phenomenon associated with training deep models. Simply put, weight changes in early layers cause major changes in distribution of inputs to later layers, making it difficult to train later layers.
#
# [Batch Normalization](https://arxiv.org/abs/1502.03167) addresses this problem by normalizing distributions of inputs to layers within mini-batches. It typically allows to train networks faster and/or with higher learning rates, lessens the importance
# of initialization and might eliminate the need for Dropout.
#
# Implement Batch Normalization and compare with regular training of MNIST models.
#
# Remember to use the batch statistics during model training and to use an average of training batch statistics during model evaluation. For details please consult the paper.

# %% [markdown]
# # Problem 6: Norm Constraints [1p bonus]
#
# Implement norm constraints, i.e. instead of weight decay, that tries to set
# all weights to small values, apply a limit on the total
# norm of connections incoming to a neuron. In our case, this
# corresponds to clipping the norm of *rows* of weight
# matrices. An easy way of implementing it is to make a gradient
# step, then look at the norm of rows and scale down those that are
# over the threshold (this technique is called "projected gradient descent").
#
# Please consult the Dropout paper (http://arxiv.org/pdf/1207.0580.pdf) for details.

# %% [markdown]
# # Problem 6: Polyak Averaging [1p bonus]
#
# Implement Polyak averaging. For each parameter $\theta$
# keep a separate, exponentially decayed average of the past values
# $$
# \bar{\theta}_n = \alpha_p\bar{\theta}_{n-1} + (1-\alpha_p)\theta_n.
# $$
# Use that average when evaluating the model on the test set.
# Validate the approach by training a model on the MNIST dataset.

# %% [markdown]
# # Problem 7: Convolutional Network [2p bonus]
#
# Use convolutional and max-pooling layers (`torch.nn.functional.conv2d`, `torch.nn.functional.max_pool2d`) and (without dropout) get a test error rate below 1.5%.

# %% [markdown]
# # Problem 8: Hyperparameter tuner [1p bonus]
#
# Implement a hyper-parameter tuner able to optimize the learing rate schedule, number of neurons and similar hyperparameters. For start, use random search (please see http://jmlr.csail.mit.edu/papers/volume13/bergstra12a/bergstra12a.pdf and especially Fig 1. for intuitions on why random search is better than grid search). It may be a good idea to use a fixed maximum number of epochs (or training time) for each optimization trial to prevent selecting hyperparameters that yield slowly converging solutions. A good result will be a set of hyperparameters that reach on MNIST solutions with test errors less than $1.3\%$ in no more than 50 epochs.
